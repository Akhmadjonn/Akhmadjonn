# %% [markdown]
# # Ransdom Forest Model

# %%
# Kutubxonalar

import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sb
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split, RandomizedSearchCV, cross_val_score, KFold
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.metrics import make_scorer, r2_score, mean_squared_error

# %%
df = pd.read_csv('StressLevelDataset.csv')

# %%
df.head()
# Out:
#    anxiety_level  self_esteem  ...  bullying  stress_level
# 0             14           20  ...         2             1
# 1             15            8  ...         5             2
# 2             12           18  ...         2             1
# 3             16           12  ...         5             2
# 4             16           28  ...         5             1
#
# [5 rows x 21 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1100 entries, 0 to 1099
# Data columns (total 21 columns):
#  #   Column                        Non-Null Count  Dtype
# ---  ------                        --------------  -----
#  0   anxiety_level                 1100 non-null   int64
#  1   self_esteem                   1100 non-null   int64
#  2   mental_health_history         1099 non-null   float64
#  3   depression                    1098 non-null   float64
#  4   headache                      1097 non-null   float64
#  5   blood_pressure                1099 non-null   float64
#  6   sleep_quality                 1099 non-null   float64
#  7   breathing_problem             1098 non-null   float64
#  8   noise_level                   1097 non-null   float64
#  9   living_conditions             1099 non-null   float64
#  10  safety                        1099 non-null   float64
#  11  basic_needs                   1098 non-null   float64
#  12  academic_performance          1099 non-null   float64
#  13  study_load                    1099 non-null   float64
#  14  teacher_student_relationship  1097 non-null   float64
#  15  future_career_concerns        1099 non-null   float64
#  16  social_support                1097 non-null   float64
#  17  peer_pressure                 1100 non-null   int64
#  18  extracurricular_activities    1100 non-null   int64
#  19  bullying                      1100 non-null   int64
#  20  stress_level                  1100 non-null   int64
# dtypes: float64(15), int64(6)
# memory usage: 180.6 KB

# %%
df.isnull().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           1
# depression                      2
# headache                        3
# blood_pressure                  1
# sleep_quality                   1
# breathing_problem               2
# noise_level                     3
# living_conditions               1
# safety                          1
# basic_needs                     2
# academic_performance            1
# study_load                      1
# teacher_student_relationship    3
# future_career_concerns          1
# social_support                  3
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %%
#Filling gaps in the dataset

for col in df.columns:
    if df[col].isnull().sum()>0:
        df[col].fillna(df[col].mean(), inplace=True)

# %%
df.isnull().sum()
# Out:
# anxiety_level                   0
# self_esteem                     0
# mental_health_history           0
# depression                      0
# headache                        0
# blood_pressure                  0
# sleep_quality                   0
# breathing_problem               0
# noise_level                     0
# living_conditions               0
# safety                          0
# basic_needs                     0
# academic_performance            0
# study_load                      0
# teacher_student_relationship    0
# future_career_concerns          0
# social_support                  0
# peer_pressure                   0
# extracurricular_activities      0
# bullying                        0
# stress_level                    0
# dtype: int64

# %%
# split data to X, Y

x=df.drop('anxiety_level',axis=1)
y=df['anxiety_level']

# %%
x.head(1)
# Out:
#    self_esteem  mental_health_history  ...  bullying  stress_level
# 0           20                    0.0  ...         2             1
#
# [1 rows x 20 columns]

# %%
y.head(1)
# Out:
# 0    14
# Name: anxiety_level, dtype: int64

# %%
#Split data to test,train,valid

x_train,x_temp,y_train,y_temp=train_test_split(x,y,test_size=0.2, random_state=42)
x_val,x_test,y_val,y_test=train_test_split(x_temp,y_temp,test_size=0.5,random_state=42)

# %%
x_train
# Out:
#       self_esteem  mental_health_history  ...  bullying  stress_level
# 507            17                    0.0  ...         2             1
# 551            17                    0.0  ...         3             1
# 290            30                    1.0  ...         3             0
# 2              18                    1.0  ...         2             1
# 6              26                    0.0  ...         1             0
# ...           ...                    ...  ...       ...           ...
# 466             6                    1.0  ...         5             2
# 121             0                    1.0  ...         5             2
# 1044            1                    1.0  ...         5             2
# 1095           17                    0.0  ...         3             1
# 860            15                    1.0  ...         2             1
#
# [880 rows x 20 columns]

# %%
#Selecting Model

model=RandomForestRegressor()

# %%
#Training Model

model.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
#Prediction 

y_pred=model.predict(x_test)

y_pred
# Out:
# array([11.99,  4.39, 10.89, 11.09,  1.63,  6.51, 18.41,  3.47,  8.89,
#         3.85, 17.29, 13.79, 18.13, 11.44, 11.16, 11.44,  5.46, 11.3 ,
#        10.91, 12.29, 11.43,  9.24, 11.57, 17.41, 17.74, 10.92,  5.17,
#         3.66,  4.32, 11.13, 19.2 , 12.39, 11.26, 11.39, 11.43, 17.  ,
#         4.24, 16.9 , 17.37,  4.18, 19.29,  8.38, 18.51, 10.29, 10.7 ,
#         9.83,  5.7 ,  4.26, 10.41,  4.48, 11.47, 18.1 , 11.3 ,  3.9 ,
#        17.86,  2.23,  4.17, 12.15, 18.3 , 17.3 , 17.66, 11.31, 19.17,
#        17.92, 18.62,  4.97,  4.38,  3.32, 11.41, 12.82, 11.07, 18.97,
#         4.75, 12.12,  5.  , 11.64, 11.49, 12.14, 10.89,  3.91, 17.52,
#        17.74, 11.79,  4.54, 17.88, 12.05, 18.67,  8.52, 17.92, 18.39,
#        17.81, 17.77, 11.56,  2.88, 17.96, 11.52,  5.2 ,  4.97, 12.34,
#        10.15, 12.1 , 14.44, 10.57,  3.49,  3.59,  5.11, 19.01,  5.75,
#         5.23,  4.3 ])

# %%
#Cheking

mse=mean_squared_error(y_test,y_pred)
r2=r2_score(y_test,y_pred)

print(mse)
print(r2)
# Out:
# 11.657605454545454
# 0.7089381238019186

# %%
#Scaling 
scaler_x=StandardScaler()
scaler_y=StandardScaler()

# %%
x_train_scaled=scaler_x.fit_transform(x_train)
x_test_scaled=scaler_x.transform(x_test)

# %%
y_train_scaled = scaler_y.fit_transform(y_train.values.reshape(-1, 1))
y_test_scaled = scaler_y.transform(y_test.values.reshape(-1, 1))

# %%
model=RandomForestRegressor()
model.fit(x_train_scaled,y_train_scaled)
# Out:
# c:\Users\ajou\AppData\Local\Programs\Python\Python313\Lib\site-packages\sklearn\base.py:1473: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   return fit_method(estimator, *args, **kwargs)
# RandomForestRegressor()

# %%
y_pred_scaled=model.predict(x_test_scaled)

# %%
mse=mean_squared_error(y_test_scaled,y_pred_scaled)
r2=r2_score(y_test_scaled, y_pred_scaled)

print(mse)
print(r2)
# Out:
# 0.3043605664777228
# 0.7161401505068825

# %%
# K-fold cross validation 

kf=KFold(n_splits=5, shuffle=True,random_state=42)

# %%
x_scaled=scaler_x.fit_transform(x)

# %%
mse=cross_val_score(model,x_scaled,y,cv=kf)

print(mse)
# Out:
# [0.7159006  0.68364602 0.66908223 0.64352623 0.66591139]

# %%
avg_mse=-np.mean(mse)

avg_mse
# Out:
# np.float64(-0.6756132953399788)
